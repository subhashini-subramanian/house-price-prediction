# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\Admin\Desktop\AI\datasets\housedata.csv")

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  condition  grade  sqft_above  sqft_basement  \
# 0      5650     1.0          3      7        1180              0
# 1      7242     2.0          3      7        2170            400
# 2     10000     1.0          3      6         770              0
# 3      5000     1.0          5      7        1050            910
# 4      8080     1.0          3      8        1680              0
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# ...

# %%
dataset.isnull().any()
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
x=dataset.iloc[0:1500,3:14].values
y=dataset.iloc[0:1500,2].values

# %%
x
# Out:
# array([[3.000e+00, 1.000e+00, 1.180e+03, ..., 0.000e+00, 1.340e+03,
#         5.650e+03],
#        [3.000e+00, 2.250e+00, 2.570e+03, ..., 4.000e+02, 1.690e+03,
#         7.639e+03],
#        [2.000e+00, 1.000e+00, 7.700e+02, ..., 0.000e+00, 2.720e+03,
#         8.062e+03],
#        ...,
#        [3.000e+00, 3.500e+00, 1.820e+03, ..., 3.900e+02, 1.550e+03,
#         1.460e+03],
#        [4.000e+00, 3.000e+00, 3.470e+03, ..., 1.100e+03, 2.420e+03,
#         4.761e+03],
#        [4.000e+00, 2.750e+00, 3.370e+03, ..., 1.260e+03, 2.460e+03,
#         7.634e+03]])

# %%
y
# Out:
# array([ 221900.,  538000.,  180000., ...,  499950., 1220000.,  720000.])

# %%
x.shape
# Out:
# (1500, 11)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(units=11,init="random_uniform",activation="relu"))
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=11, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units=22,init="random_uniform",activation="relu"))
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=22, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units=44,init="random_uniform",activation="relu"))
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=44, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units=1,init="random_uniform",activation="relu"))
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.compile(optimizer="adam",loss="mse",metrics=["mse"])

# %%
model.fit(x_train,y_train,epochs=1000,batch_size=32)
# Out:
# Epoch 1/1000
# 1200/1200 [==============================] - 0s 58us/step - loss: 51922433720.3200 - mean_squared_error: 51922433720.3200
# Epoch 2/1000
# 1200/1200 [==============================] - 0s 54us/step - loss: 51901265920.0000 - mean_squared_error: 51901265920.0000
# Epoch 3/1000
# 1200/1200 [==============================] - 0s 57us/step - loss: 51927043713.7067 - mean_squared_error: 51927043713.7067
# Epoch 4/1000
# 1200/1200 [==============================] - 0s 51us/step - loss: 51919709689.1733 - mean_squared_error: 51919709689.1733
# Epoch 5/1000
# 1200/1200 [==============================] - 0s 50us/step - loss: 51888746386.7733 - mean_squared_error: 51888746386.7733
# Epoch 6/1000
# 1200/1200 [==============================] - 0s 53us/step - loss: 51889295714.9867 - mean_squared_error: 51889295714.9867
# Epoch 7/1000
# 1200/1200 [==============================] - 0s 48us/step - loss: 51938380868.2667 - mean_squared_error: 51938380868.2667
# Epoch 8/1000
# ...

# %%
y_pred=model.predict(x_test)

# %%
y_pred[0]
# Out:
# array([1060874.5], dtype=float32)

# %%
y_test[0]
# Out:
# 868700.0

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.508200963847363
